# %%
import os
from dotenv import load_dotenv
from mp_api.client import MPRester
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load API Key securely
load_dotenv()
api_key = os.getenv("04bjlSnlXBJDBbOJjvORn0PtAXCY8rDw")
