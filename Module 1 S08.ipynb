# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/anaconda3/envs/mpapi311/lib/python3.11/site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/envs/mpapi311/lib/python3.11/site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/anaconda3/envs/mpapi311/lib/python3.11/site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/mpapi311/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/mpapi311/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /opt/anaconda3/envs/mpapi311/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/mpapi311/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/mpapi311/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.1)
# Requirement already satisfied: pillow>=9 in /opt/anaconda3/envs/mpapi311/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/mpapi311/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/mpapi311/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/mpapi311/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
from mp_api.client import MPRester
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load API Key securely
load_dotenv()
api_key = os.getenv("yMkgHg0OjbuuR9LHQQ4oR5Exu5acXVTF")

# %%
from mp_api.client import MPRester

API_KEY = "yMkgHg0OjbuuR9LHQQ4oR5Exu5acXVTF"

try:
    with MPRester(API_KEY) as mpr:

        docs = mpr.materials.summary.search(
            elements=["O"],
            num_elements=(2, 2),
            fields=[
                "material_id",
                "formula_pretty",
                "band_gap",
                "elements"
            ]
        )

        # Sirf jinka band gap hai unko print karo
        docs = [doc for doc in docs if doc.band_gap is not None]

        print(f"Found {len(docs)} materials")

        for doc in docs[:10]:
            print(
                f"{doc.material_id} | {doc.formula_pretty} | Band Gap = {doc.band_gap} eV"
            )

except Exception as e:
    print("Error:", e)
# Out:
# Retrieving SummaryDoc documents: 100%|████████████████████████████████████████████| 2548/2548 [00:02<00:00, 958.76it/s]
# Found 2548 materials
# mp-1950989 | BaO | Band Gap = 2.5282 eV
# mp-1974948 | Na2O | Band Gap = 2.6124 eV
# mp-1974703 | FeO | Band Gap = 0.5488999999999997 eV
# mp-1975297 | Na2O | Band Gap = 1.6666999999999998 eV
# mp-1974672 | K2O | Band Gap = 1.3903999999999999 eV
# mp-1974803 | H2O | Band Gap = 6.127800000000001 eV
# mp-1975124 | K2O | Band Gap = 2.2661 eV
# mp-2023482 | Rb2O | Band Gap = 0.7837000000000001 eV
# mp-2039648 | CrO | Band Gap = 0.0 eV
# mp-2346983 | ZnO | Band Gap = 0.8378 eV
